# %% [markdown]
# ## Regresion Lineal
#
# *Alan Solano*
#
# ### repositorio: https://github.com/ingealan/machinelearning1/blob/main/act/incidenteinformatico.ipynb

# %% [markdown]
# # Regresión Lineal: Coste de un incidente de seguridad

# %% [markdown]
# En este ejercicio se explican los fundamentos básicos de la regresión lineal aplicada a un caso de uso sencillo relacionado con la Ciberseguridad.

# %% [markdown]
# ## Enunciado del ejercicio

# %% [markdown]
# El ejercicio consiste en predecir el coste de un incidente de seguridad en base al número de equipos que se han visto afectados. El conjunto de datos es generado de manera aleatoria.

# %% [markdown]
# ### 0. Imports

# %%
# Instalacion de librerías externas
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### 1. Generación del conjunto de datos

# %%
X = 2 * np.random.rand(1000, 1)
y = 4 + 3 * X + np.random.randn(1000, 1)

print("La longitud del conjunto de datos es:", len(X))
# Out:
# La longitud del conjunto de datos es: 1000

# %% [markdown]
# ### 2. Visualización del conjunto de datos

# %%
plt.scatter(X, y, color='blue')
plt.xlabel("Número de equipos afectados")
plt.ylabel("Coste del incidente (€)")
plt.title("Coste vs Equipos afectados")
plt.show()

# %% [markdown]
# ### 3. Modificación del conjunto de datos

# %%
X = X.astype(int)

# %% [markdown]
# ### 4. Construcción del modelo

# %%
modelo = LinearRegression()

modelo.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### 5. Predicción de nuevos ejemplos

# %%
nuevo_ejemplo = np.array([[1]])

coste_predicho = modelo.predict(nuevo_ejemplo)

print(f"Predicción del coste para {nuevo_ejemplo[0][0]} equipos afectados: {coste_predicho[0][0]:.2f}")
# Out:
# Predicción del coste para 1 equipos afectados: 8.46
